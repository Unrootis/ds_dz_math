# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import dot
from numpy.linalg import norm


from scipy.optimize import minimize
import scipy.stats as sts

# %% [markdown]
# #### Задание 1

# %%
raitings = np.array([[ 4,  4,  9,  4,  1,  6, 10,  7,  9,  6,  9,  2,  8,  6,  6],
                     [ 9,  2,  5, 10,  7,  8, 10,  5,  6,  2,  1,  6,  8,  9,  7],
                     [ 1,  6,  8,  8,  4,  9,  3,  8, 10,  5,  2,  6,  8,  1,  6],
                     [ 6,  1,  9,  7,  7,  9,  2,  3,  5,  1,  6,  6,  3,  2,  7],
                     [ 3,  7,  3,  5,  7,  9,  9,  6,  2,  9,  1,  2,  8, 10,  6],
                     [ 8,  3,  7,  3,  8,  6,  1,  8,  8,  6,  1,  9,  4, 10,  1],
                     [ 9,  8,  4,  8,  8, 10,  6,  1,  1,  2,  9,  5,  2,  7,  2],
                     [ 4,  1,  6,  4,  3, 10,  4,  4,  2,  8,  7,  9,  3,  8,  3],
                     [ 2,  7,  7,  6, 10,  6,  8,  9,  8,  6, 10,  1,  7, 10,  4],
                     [ 5, 10,  8,  8,  9,  7,  2,  9,  9, 10,  8,  8,  8,  6, 10]])
cos_sim=np.array([])
for item_1 in enumerate(raitings): ##не отрабатывает, как хотелось бы - оставляет только послудний результат прогона цикла
    for item_2 in enumerate(raitings): ##не отрабатывает, как хотелось бы - оставляет только послудний результат прогона цикла
        cos_sim = dot(item_1[1], item_2[1])/(norm(item_1[1])*norm(item_2[1])) ##перемножение всех массивов
        cos_sim=np.append((item_1[0],item_2[0]), cos_sim) ##для удобства визуализации
cos_sim
# Out:
# array([9., 9., 1.])

# %% [markdown]
# #### Задание 2

# %%
from sympy import diff, symbols, cos, sin, tan
x=symbols('x')
y=diff(tan(sin(x)+cos(2*x+3))**2)
y.evalf(4,subs={x:1})
# Out:
# 55.39

# %% [markdown]
# #### Задание 3

# %%
a, b=(3, -2.5)
params=([a,b])

def f(x, a, b):
    return np.e**a * np.sin(b*x) + x
x = np.array([0.        , 0.26315789, 0.52631579, 0.78947368, 1.05263158,
              1.31578947, 1.57894737, 1.84210526, 2.10526316, 2.36842105,
              2.63157895, 2.89473684, 3.15789474, 3.42105263, 3.68421053,
              3.94736842, 4.21052632, 4.47368421, 4.73684211, 5.        ])
fx = np.array([  0.        , -12.01819092, -18.90968634, -17.68786571,
                -8.7529108 ,   4.27524517,  16.06801336,  21.81250213,
                19.22059845,   9.48411207,  -3.22273056, -13.48576488,
               -16.91096359, -11.95866834,  -0.58630088,  12.56873816,
                22.12489421,  24.20292139,  18.04522521,   6.33211092])
plt.plot(x, fx)
plt.plot(x, f(x,a,b))
plt.show()

def error(params):
    return np.sum(np.abs(fx - f(x, params[0], params[1])))
error(params)
# Out:
# 1.5163282505170628e-06

# %% [markdown]
# #### Задание 4

# %%
f=np.random.randint(0,21,size=(1000, 50))

x=np.linspace(0,15,100)
plt.hist(sample, density=True, bins=20, label='sample histogram')
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

samples_count=1000
a1=np.array([])
i=0

for number in range(samples_count):
    sample=f[i]
    a1=np.append(a1, sample.mean())
    i=i+1

label_1='sample of 50 histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %% [markdown]
# #### Задание 5

# %%
m=np.array([[1, 4],
            [1, 1]])
n=np.linalg.eig(m)
n
# Out:
# (array([ 3., -1.]),
#  array([[ 0.89442719, -0.89442719],
#         [ 0.4472136 ,  0.4472136 ]]))
